# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset/property_data.csv")

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df['OWN_OCCUPIED']
# Out:
# 0      Y
# 1      N
# 2      N
# 3    NaN
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: OWN_OCCUPIED, dtype: object

# %%
missing_values = ["n/a", "na", "--"]

# %%
df = pd.read_csv("dataset/property_data.csv", na_values = missing_values)

# %%
cnt=0
for row in df['OWN_OCCUPIED']:
    try:
        int(row)
        df.loc[cnt, 'OWN_OCCUPIED']=np.nan
    except ValueError:
        pass
    cnt+=1

# %%
int("55")
# Out:
# 55

# %%
df.isnull().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    2
# NUM_BATH        1
# SQ_FT           1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           8 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       9 non-null      object
#  3   OWN_OCCUPIED  7 non-null      object
#  4   NUM_BEDROOMS  7 non-null      object
#  5   NUM_BATH      8 non-null      object
#  6   SQ_FT         8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 388.0+ bytes

# %%
df.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0     PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0   BERKELEY          NaN            1      NaN   700
# 4          NaN   203.0   BERKELEY            Y            3        2  1600

# %%
df['ST_NUM'].fillna(125, inplace=True)

# %%
df.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0     PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 2  100003000.0   125.0  LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0   BERKELEY          NaN            1      NaN   700
# 4          NaN   203.0   BERKELEY            Y            3        2  1600

# %%
# %matplotlib inline
data = pd.ExcelFile('dataset/obes.xls')

# %%
data

# %%
data_age = data.parse(u'7.2', skiprows=4, skipfooter=14)

# %%
data_age
# Out:
#    Unnamed: 0    Total  Under 16  16-24   25-34   35-44   45-54   55-64  \
# 0         NaN      NaN       NaN    NaN     NaN     NaN     NaN     NaN
# 1     2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0
# 2     2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0
# 3     2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0
# 4     2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0
# 5     2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0
# 6     2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0
# 7     2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0
# 8     2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0
# 9     2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0
# 10    2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0
# 11    2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0
#
#     65-74  75 and over
# ...

# %%
data_age.rename(columns={u'Unnamed: 0': u'Year'}, inplace=True)

# %%
data_age.dropna(inplace=True)

# %%
data_age
# Out:
#        Year    Total  Under 16  16-24   25-34   35-44   45-54   55-64  65-74  \
# 1   2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0   52.0
# 2   2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0   52.0
# 3   2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0   36.0
# 4   2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0   72.0
# 5   2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0  118.0
# 6   2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0  157.0
# 7   2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0  221.0
# 8   2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0  378.0
# 9   2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0  456.0
# 10  2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0  468.0
# 11  2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0  495.0
#
#     75 and over
# 1          23.0
# ...

# %%
data_age.set_index('Year', inplace=True)

# %%
data_age
# Out:
#            Total  Under 16  16-24   25-34   35-44   45-54   55-64  65-74  \
# Year
# 2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0   52.0
# 2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0   52.0
# 2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0   36.0
# 2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0   72.0
# 2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0  118.0
# 2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0  157.0
# 2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0  221.0
# 2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0  378.0
# 2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0  456.0
# 2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0  468.0
# 2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0  495.0
#
#          75 and over
# Year
# 2002/03         23.0
# 2003/04         24.0
# ...

# %%
data_age_minus_total = data_age.drop('Total', axis=1)

# %%
data_age_minus_total.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
data_age['Under 16'].plot(label="Under 16", legend=True)
data_age['35-44'].plot(label="35-44", legend=True)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
from datetime import datetime

# %%
date_rng = pd.date_range(start='1/01/2020', end='1/08/2020', freq='H')

# %%
date_rng
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                ...
#                '2020-01-07 15:00:00', '2020-01-07 16:00:00',
#                '2020-01-07 17:00:00', '2020-01-07 18:00:00',
#                '2020-01-07 19:00:00', '2020-01-07 20:00:00',
#                '2020-01-07 21:00:00', '2020-01-07 22:00:00',
#                '2020-01-07 23:00:00', '2020-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='H')

# %%
df = pd.DataFrame(date_rng, columns=['date'])

# %%
df['datas'] = np.random.randint(0,100,size=(len(date_rng)))

# %%
df
# Out:
#                    date  datas
# 0   2020-01-01 00:00:00     27
# 1   2020-01-01 01:00:00     15
# 2   2020-01-01 02:00:00     27
# 3   2020-01-01 03:00:00      1
# 4   2020-01-01 04:00:00     29
# ..                  ...    ...
# 164 2020-01-07 20:00:00     70
# 165 2020-01-07 21:00:00     47
# 166 2020-01-07 22:00:00     74
# 167 2020-01-07 23:00:00     28
# 168 2020-01-08 00:00:00     50
#
# [169 rows x 2 columns]

# %%
df.set_index('date', inplace=True)

# %%
df[
    df.index.day==2
]
# Out:
#                      datas
# date
# 2020-01-02 00:00:00     86
# 2020-01-02 01:00:00     76
# 2020-01-02 02:00:00     29
# 2020-01-02 03:00:00     55
# 2020-01-02 04:00:00      7
# 2020-01-02 05:00:00     90
# 2020-01-02 06:00:00     98
# 2020-01-02 07:00:00     12
# 2020-01-02 08:00:00     45
# 2020-01-02 09:00:00     83
# 2020-01-02 10:00:00     48
# 2020-01-02 11:00:00     70
# 2020-01-02 12:00:00     73
# 2020-01-02 13:00:00     67
# 2020-01-02 14:00:00     19
# 2020-01-02 15:00:00     88
# 2020-01-02 16:00:00     13
# 2020-01-02 17:00:00     56
# 2020-01-02 18:00:00     14
# 2020-01-02 19:00:00     27
# 2020-01-02 20:00:00     39
# 2020-01-02 21:00:00     66
# 2020-01-02 22:00:00     53
# 2020-01-02 23:00:00     52

# %%
df['2020-01-01']
# Out:
#                      datas
# date
# 2020-01-01 00:00:00     27
# 2020-01-01 01:00:00     15
# 2020-01-01 02:00:00     27
# 2020-01-01 03:00:00      1
# 2020-01-01 04:00:00     29
# 2020-01-01 05:00:00     42
# 2020-01-01 06:00:00     82
# 2020-01-01 07:00:00     35
# 2020-01-01 08:00:00     36
# 2020-01-01 09:00:00     85
# 2020-01-01 10:00:00     25
# 2020-01-01 11:00:00     67
# 2020-01-01 12:00:00     15
# 2020-01-01 13:00:00     15
# 2020-01-01 14:00:00     67
# 2020-01-01 15:00:00     45
# 2020-01-01 16:00:00     28
# 2020-01-01 17:00:00     34
# 2020-01-01 18:00:00     68
# 2020-01-01 19:00:00     20
# 2020-01-01 20:00:00     14
# 2020-01-01 21:00:00     17
# 2020-01-01 22:00:00     84
# 2020-01-01 23:00:00     98

# %%
df.resample('H').sum()
# Out:
#                      datas
# date
# 2020-01-01 00:00:00     27
# 2020-01-01 01:00:00     15
# 2020-01-01 02:00:00     27
# 2020-01-01 03:00:00      1
# 2020-01-01 04:00:00     29
# ...                    ...
# 2020-01-07 20:00:00     70
# 2020-01-07 21:00:00     47
# 2020-01-07 22:00:00     74
# 2020-01-07 23:00:00     28
# 2020-01-08 00:00:00     50
#
# [169 rows x 1 columns]

# %%
df['rolling_sum']=df.rolling(3).sum()

# %%
df
# Out:
#                      datas  rolling_sum
# date
# 2020-01-01 00:00:00     27          NaN
# 2020-01-01 01:00:00     15         42.0
# 2020-01-01 02:00:00     27         42.0
# 2020-01-01 03:00:00      1         28.0
# 2020-01-01 04:00:00     29         30.0
# ...                    ...          ...
# 2020-01-07 20:00:00     70         71.0
# 2020-01-07 21:00:00     47        117.0
# 2020-01-07 22:00:00     74        121.0
# 2020-01-07 23:00:00     28        102.0
# 2020-01-08 00:00:00     50         78.0
#
# [169 rows x 2 columns]

# %%
df['rolling_sum_backfilled'] = df['rolling_sum'].fillna(method='backfill')

# %%
df
# Out:
#                      datas  rolling_sum  rolling_sum_backfilled
# date
# 2020-01-01 00:00:00     27          NaN                    69.0
# 2020-01-01 01:00:00     15          NaN                    69.0
# 2020-01-01 02:00:00     27         69.0                    69.0
# 2020-01-01 03:00:00      1         43.0                    43.0
# 2020-01-01 04:00:00     29         57.0                    57.0
# ...                    ...          ...                     ...
# 2020-01-07 20:00:00     70        153.0                   153.0
# 2020-01-07 21:00:00     47        118.0                   118.0
# 2020-01-07 22:00:00     74        191.0                   191.0
# 2020-01-07 23:00:00     28        149.0                   149.0
# 2020-01-08 00:00:00     50        152.0                   152.0
#
# [169 rows x 3 columns]

# %%
opsd_daily = pd.read_csv('dataset/opsd_germany_daily.csv')

# %%
opsd_daily.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
opsd_daily.set_index('Date', inplace=True)

# %%
opsd_daily.index
# Out:
# Index(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04', '2006-01-05',
#        '2006-01-06', '2006-01-07', '2006-01-08', '2006-01-09', '2006-01-10',
#        ...
#        '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25', '2017-12-26',
#        '2017-12-27', '2017-12-28', '2017-12-29', '2017-12-30', '2017-12-31'],
#       dtype='object', name='Date', length=4383)

# %%
opsd_daily = pd.read_csv('dataset/opsd_germany_daily.csv', 
                         index_col=0, 
                         parse_dates=True)

# %%
opsd_daily
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
opsd_daily['Year']=opsd_daily.index.year
opsd_daily['Month']=opsd_daily.index.month
opsd_daily['Weekday']=opsd_daily.index.weekday

# %%
opsd_daily
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  Weekday
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1        6
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1        0
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1        1
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1        2
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1        3
# ...                 ...      ...     ...         ...   ...    ...      ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12        2
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12        3
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12        4
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12        5
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12        6
#
# [4383 rows x 7 columns]
