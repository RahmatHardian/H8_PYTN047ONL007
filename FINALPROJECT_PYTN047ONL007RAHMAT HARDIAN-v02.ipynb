# %% [markdown]
# <img src = "https://global-uploads.webflow.com/5f0d53c042a9ed6288de7f8d/5f6337ae2cfaa10946ceeb06_Hacktiv8%20logo%20horizontal%2001%20black-p-500.png" width = 400>
# <h1 align=center><font size = 5>Hacktiv8 PTP Introduction to Data Science Assignment 2 // Statistical Treatment for Retail Dataset</font></h1>

# %%
# Klasifikasi job fam ?
# kriteria pelatihan tertentu dan NIK tertentu apakah dihadiri atau tidak: ldepelatihan_absensi & tpelatihan. Data tidak seimbang

# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np

# %%
# Add the Data using pandas
Corpus_telkom = pd.read_csv("dataset/20210122-Kampiun Digilib Clean-jfam-jfunc.csv",encoding='latin-1')

# Cut data for testing
# Corpus_telkom = Corpus_telkom[:300]

Corpus_telkom
# Out:
#         source  org_id  doc_id  \
# 0      Kampiun     NaN   27243
# 1      Kampiun     NaN   29134
# 2      Kampiun     NaN   28690
# 3      Kampiun     NaN   33756
# 4      Kampiun     NaN   38567
# ...        ...     ...     ...
# 11296  Kampiun     NaN   35659
# 11297  Kampiun     NaN   38867
# 11298  Kampiun     NaN   40529
# 11299  Kampiun     NaN   39161
# 11300  Kampiun     NaN   25622
#
#                                                doc_title  \
# 0          Case Study 1 tahun Magang di Kementerian BUMN
# 1          Case Study 1 tahun Magang di Kementerian BUMN
# 2         ILC : Securing Revenue Witel Riau Daratan 2017
# 3        SIKAT HABIS FTTH UNSPEC DENGAN MINI OLT OUTDOOR
# 4      PROSES PENGAJUAN CAPEX FTTH INDIHOME DI WITEL NTB
# ...                                                  ...
# 11296                     PENTINGNYA LOYALITAS PELANGGAN
# 11297  Uji Terima Online dalam Proyek Digitalisasi SP...
# 11298  REKON TAGIHAN PSB  TA TO TELKOM  WITEL PURWOKERTO
# 11299  TDSCC  (Telkom DIGITAL SOLUTION CARE CENTER) G...
# 11300  Blockchain adoption in order  to Implement Bio...
#
#                                          doc_description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11296  Ditengah-tengah persaingan berbagai bisnis/ind...
# 11297  1. Latar Belakang           \n                ...
# 11298  CARA REKON TAGIHAN PSB  TA KE TELKOM \n \n1. A...
# 11299                                             #NAME?
# 11300                                             #NAME?
#
#                             Job Family               Job Function  \
# 0      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 1      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 2         STRATEGIC PLAN & DEVELOPMENT         Strategic Planning
# 3                        DIGITAL & ICT          Telecommunication
# 4                        DIGITAL & ICT          Telecommunication
# ...                                ...                        ...
# 11296              COMMERCE & RELATION                      Sales
# 11297                    DIGITAL & ICT     Information Technology
# 11298  BUSINESS ENABLER/ENTERPRISE MGT                  Education
# 11299                    DIGITAL & ICT     Information Technology
# 11300                    DIGITAL & ICT  DIGITAL PRODUCT & SERVICE
#
#                                          job_role  \
# 0                5.2.3 Learning &amp; Development
# 1                5.2.3 Learning &amp; Development
# 2          2.1.1 Internal &amp; External Analysis
# 3                    1.1.6 Access Network O&amp;M
# 4      1.1.2 Access Network Design &amp; Planning
# ...                                           ...
# 11296                      3.2.1 Sales Management
# 11297               1.2.2 IT Solution Development
# 11298                   5.7.3 Education Operation
# 11299                         1.2.4 IT Operations
# 11300       1.3.3 Product &amp;  Ecosystem Design
#
#                                job_role_clean
# 0                      Learning & Development
# 1                      Learning & Development
# 2                Internal & External Analysis
# 3      Access Network Operation & Maintenance
# 4            Access Network Design & Planning
# ...                                       ...
# 11296                        Sales Management
# 11297                 IT Solution Development
# 11298                     Education Operation
# 11299                           IT Operations
# 11300              Product & Ecosystem Design
#
# [11301 rows x 9 columns]

# %%
Corpus_telkom['title_desc'] = Corpus_telkom['doc_title'].astype(str)
Corpus_telkom
# Out:
#         source  org_id  doc_id  \
# 0      Kampiun     NaN   27243
# 1      Kampiun     NaN   29134
# 2      Kampiun     NaN   28690
# 3      Kampiun     NaN   33756
# 4      Kampiun     NaN   38567
# ...        ...     ...     ...
# 11296  Kampiun     NaN   35659
# 11297  Kampiun     NaN   38867
# 11298  Kampiun     NaN   40529
# 11299  Kampiun     NaN   39161
# 11300  Kampiun     NaN   25622
#
#                                                doc_title  \
# 0          Case Study 1 tahun Magang di Kementerian BUMN
# 1          Case Study 1 tahun Magang di Kementerian BUMN
# 2         ILC : Securing Revenue Witel Riau Daratan 2017
# 3        SIKAT HABIS FTTH UNSPEC DENGAN MINI OLT OUTDOOR
# 4      PROSES PENGAJUAN CAPEX FTTH INDIHOME DI WITEL NTB
# ...                                                  ...
# 11296                     PENTINGNYA LOYALITAS PELANGGAN
# 11297  Uji Terima Online dalam Proyek Digitalisasi SP...
# 11298  REKON TAGIHAN PSB  TA TO TELKOM  WITEL PURWOKERTO
# 11299  TDSCC  (Telkom DIGITAL SOLUTION CARE CENTER) G...
# 11300  Blockchain adoption in order  to Implement Bio...
#
#                                          doc_description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11296  Ditengah-tengah persaingan berbagai bisnis/ind...
# 11297  1. Latar Belakang           \n                ...
# 11298  CARA REKON TAGIHAN PSB  TA KE TELKOM \n \n1. A...
# 11299                                             #NAME?
# 11300                                             #NAME?
#
#                             Job Family               Job Function  \
# 0      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 1      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 2         STRATEGIC PLAN & DEVELOPMENT         Strategic Planning
# 3                        DIGITAL & ICT          Telecommunication
# 4                        DIGITAL & ICT          Telecommunication
# ...                                ...                        ...
# 11296              COMMERCE & RELATION                      Sales
# 11297                    DIGITAL & ICT     Information Technology
# 11298  BUSINESS ENABLER/ENTERPRISE MGT                  Education
# 11299                    DIGITAL & ICT     Information Technology
# 11300                    DIGITAL & ICT  DIGITAL PRODUCT & SERVICE
#
#                                          job_role  \
# 0                5.2.3 Learning &amp; Development
# 1                5.2.3 Learning &amp; Development
# 2          2.1.1 Internal &amp; External Analysis
# 3                    1.1.6 Access Network O&amp;M
# 4      1.1.2 Access Network Design &amp; Planning
# ...                                           ...
# 11296                      3.2.1 Sales Management
# 11297               1.2.2 IT Solution Development
# 11298                   5.7.3 Education Operation
# 11299                         1.2.4 IT Operations
# 11300       1.3.3 Product &amp;  Ecosystem Design
#
#                                job_role_clean  \
# 0                      Learning & Development
# 1                      Learning & Development
# 2                Internal & External Analysis
# 3      Access Network Operation & Maintenance
# 4            Access Network Design & Planning
# ...                                       ...
# 11296                        Sales Management
# 11297                 IT Solution Development
# 11298                     Education Operation
# 11299                           IT Operations
# 11300              Product & Ecosystem Design
#
#                                               title_desc
# 0          Case Study 1 tahun Magang di Kementerian BUMN
# 1          Case Study 1 tahun Magang di Kementerian BUMN
# 2         ILC : Securing Revenue Witel Riau Daratan 2017
# 3        SIKAT HABIS FTTH UNSPEC DENGAN MINI OLT OUTDOOR
# 4      PROSES PENGAJUAN CAPEX FTTH INDIHOME DI WITEL NTB
# ...                                                  ...
# 11296                     PENTINGNYA LOYALITAS PELANGGAN
# 11297  Uji Terima Online dalam Proyek Digitalisasi SP...
# 11298  REKON TAGIHAN PSB  TA TO TELKOM  WITEL PURWOKERTO
# 11299  TDSCC  (Telkom DIGITAL SOLUTION CARE CENTER) G...
# 11300  Blockchain adoption in order  to Implement Bio...
#
# [11301 rows x 10 columns]

# %%
Corpus_telkom.drop([
    'doc_title','doc_description','source', 'org_id', 'doc_id', 'job_role','job_role_clean'
], axis=1, inplace=True)
Corpus_telkom
# Out:
#                             Job Family               Job Function  \
# 0      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 1      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 2         STRATEGIC PLAN & DEVELOPMENT         Strategic Planning
# 3                        DIGITAL & ICT          Telecommunication
# 4                        DIGITAL & ICT          Telecommunication
# ...                                ...                        ...
# 11296              COMMERCE & RELATION                      Sales
# 11297                    DIGITAL & ICT     Information Technology
# 11298  BUSINESS ENABLER/ENTERPRISE MGT                  Education
# 11299                    DIGITAL & ICT     Information Technology
# 11300                    DIGITAL & ICT  DIGITAL PRODUCT & SERVICE
#
#                                               title_desc
# 0          Case Study 1 tahun Magang di Kementerian BUMN
# 1          Case Study 1 tahun Magang di Kementerian BUMN
# 2         ILC : Securing Revenue Witel Riau Daratan 2017
# 3        SIKAT HABIS FTTH UNSPEC DENGAN MINI OLT OUTDOOR
# 4      PROSES PENGAJUAN CAPEX FTTH INDIHOME DI WITEL NTB
# ...                                                  ...
# 11296                     PENTINGNYA LOYALITAS PELANGGAN
# 11297  Uji Terima Online dalam Proyek Digitalisasi SP...
# 11298  REKON TAGIHAN PSB  TA TO TELKOM  WITEL PURWOKERTO
# 11299  TDSCC  (Telkom DIGITAL SOLUTION CARE CENTER) G...
# 11300  Blockchain adoption in order  to Implement Bio...
#
# [11301 rows x 3 columns]

# %%
Corpus_telkom.dropna(inplace=True)
Corpus_telkom.isna().sum()
# Out:
# Job Family      0
# Job Function    0
# title_desc      0
# dtype: int64

# %%
Corpus_telkom
# Out:
#                             Job Family               Job Function  \
# 0      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 1      BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 2         STRATEGIC PLAN & DEVELOPMENT         Strategic Planning
# 3                        DIGITAL & ICT          Telecommunication
# 4                        DIGITAL & ICT          Telecommunication
# ...                                ...                        ...
# 11296              COMMERCE & RELATION                      Sales
# 11297                    DIGITAL & ICT     Information Technology
# 11298  BUSINESS ENABLER/ENTERPRISE MGT                  Education
# 11299                    DIGITAL & ICT     Information Technology
# 11300                    DIGITAL & ICT  DIGITAL PRODUCT & SERVICE
#
#                                               title_desc
# 0          Case Study 1 tahun Magang di Kementerian BUMN
# 1          Case Study 1 tahun Magang di Kementerian BUMN
# 2         ILC : Securing Revenue Witel Riau Daratan 2017
# 3        SIKAT HABIS FTTH UNSPEC DENGAN MINI OLT OUTDOOR
# 4      PROSES PENGAJUAN CAPEX FTTH INDIHOME DI WITEL NTB
# ...                                                  ...
# 11296                     PENTINGNYA LOYALITAS PELANGGAN
# 11297  Uji Terima Online dalam Proyek Digitalisasi SP...
# 11298  REKON TAGIHAN PSB  TA TO TELKOM  WITEL PURWOKERTO
# 11299  TDSCC  (Telkom DIGITAL SOLUTION CARE CENTER) G...
# 11300  Blockchain adoption in order  to Implement Bio...
#
# [11301 rows x 3 columns]

# %%
# ubah semua jadi lower case
Corpus_telkom['title_desc'] = [str(entry).lower() for entry in Corpus_telkom['title_desc']]

# %%
from nltk.tokenize import word_tokenize
# Tokenization : kalimat dipecah menjadi perkata
Corpus_telkom['title_desc']= [word_tokenize(entry) for entry in Corpus_telkom['title_desc']]

# %%
from collections import defaultdict
from nltk.corpus import wordnet as wn

# ###
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

# %%
# stopwords, stemming and storing
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import stopwords

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()


for index, entry in enumerate(Corpus_telkom['title_desc']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('indonesian') and word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            word_Final = stemmer.stem(word_Final)
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    Corpus_telkom.loc[index,'title_desc_final'] = str(Final_words)

# %%
Corpus_telkom.head(10)
# Out:
#                         Job Family               Job Function  \
# 0  BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 1  BUSINESS ENABLER/ENTERPRISE MGT              Human Capital
# 2     STRATEGIC PLAN & DEVELOPMENT         Strategic Planning
# 3                    DIGITAL & ICT          Telecommunication
# 4                    DIGITAL & ICT          Telecommunication
# 5                    DIGITAL & ICT  DIGITAL PRODUCT & SERVICE
# 6                    DIGITAL & ICT          Telecommunication
# 7              COMMERCE & RELATION                  Marketing
# 8     STRATEGIC PLAN & DEVELOPMENT       Business Development
# 9  BUSINESS ENABLER/ENTERPRISE MGT            General Affairs
#
#                                           title_desc  \
# 0  [case, study, 1, tahun, magang, di, kementeria...
# 1  [case, study, 1, tahun, magang, di, kementeria...
# 2  [ilc, :, securing, revenue, witel, riau, darat...
# 3  [sikat, habis, ftth, unspec, dengan, mini, olt...
# 4  [proses, pengajuan, capex, ftth, indihome, di,...
# 5  [customer, validation, -, omega, (, home, shop...
# 6  [osase, sebagai, inisiator, monitoring, catu, ...
# 7  [mambangun, budaya, peta, tuan, melalui, kreas...
# 8  [special, offers, program, for, digiconnect, v...
# 9  [analisa, performansi, revenue, bges, ytd, apr...
#
#                                     title_desc_final
# 0     ['case', 'study', 'magang', 'menteri', 'bumn']
# 1     ['case', 'study', 'magang', 'menteri', 'bumn']
# 2  ['ilc', 'securing', 'revenue', 'witel', 'riau'...
# 3  ['sikat', 'habis', 'ftth', 'unspec', 'mini', '...
# 4  ['prose', 'aju', 'capex', 'ftth', 'indihome', ...
# 5  ['customer', 'validation', 'omega', 'home', 's...
# 6  ['osase', 'inisiator', 'monitoring', 'catu', '...
# 7  ['mambangun', 'budaya', 'peta', 'tuan', 'kreasi']
# 8  ['special', 'offer', 'program', 'digiconnect',...
# 9  ['analisa', 'performansi', 'revenue', 'bges', ...

# %% [markdown]
# # Creating Model

# %%
from sklearn import model_selection, naive_bayes, svm
from sklearn.preprocessing import LabelEncoder

Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(Corpus_telkom['title_desc_final'], Corpus_telkom['Job Family'], test_size=0.3, random_state=4)

Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Step - 4: Vectorize the words by using TF-IDF Vectorizer - This is done to find how important a word in document is in comaprison to the corpus
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(Train_X)

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
Train_X.head()
# Out:
# 10100         ['review', 'risk', 'profile', 'telkomgroup']
# 7339     ['accu', 'mini', 'solusi', 'jitu', 'catu', 'mo...
# 9391     ['fun', 'activity', 'scoreboard', 'base', 'the...
# 8274     ['ada', 'jasa', 'sewa', 'manage', 'service', '...
# 10619                             ['transfer', 'nowledge']
# Name: title_desc_final, dtype: object

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier


# Step - 5: Now we can run different algorithms to classify out data check for accuracy

# Classifier - Algorithm - Naive Bayes
# fit the training dataset on the classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)


# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)

# Classifier - Algorithm - Random Forest
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(Train_X_Tfidf,Train_Y)
predictions_clf = clf.predict(Test_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("Random Forest Accuracy Score -> ",accuracy_score(predictions_clf, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  58.95016219404305
# SVM Accuracy Score ->  60.306694190504274
# Random Forest Accuracy Score ->  61.45679740489531

# %%
# Corpus_telkom['Job Function']

# %%
clf.classes_
# Out:
# array([0, 1, 2, 3, 4])

# %%
SVM.predict(Tfidf_vect.transform(['IT Teknologi']))
# Out:
# array([2])

# %%
Corpus_telkom['Job Family']
# Out:
# 0        BUSINESS ENABLER/ENTERPRISE MGT
# 1        BUSINESS ENABLER/ENTERPRISE MGT
# 2           STRATEGIC PLAN & DEVELOPMENT
# 3                          DIGITAL & ICT
# 4                          DIGITAL & ICT
#                       ...
# 11296                COMMERCE & RELATION
# 11297                      DIGITAL & ICT
# 11298    BUSINESS ENABLER/ENTERPRISE MGT
# 11299                      DIGITAL & ICT
# 11300                      DIGITAL & ICT
# Name: Job Family, Length: 11301, dtype: object

# %%
# predicted = pd.DataFrame(Encoder.inverse_transform(predictions_SVM), columns=['predicted label'], index=Test_X.to_frame().index)
# predicted
Encoder.inverse_transform(SVM.classes_)
# Out:
# array(['BUSINESS ENABLER/ENTERPRISE MGT', 'COMMERCE & RELATION',
#        'DIGITAL & ICT', 'RISK & COMPLIANCE',
#        'STRATEGIC PLAN & DEVELOPMENT'], dtype=object)

# %%
predicted = pd.DataFrame(Encoder.inverse_transform(SVM.classes_), columns=['predicted label'])
predicted
# Out:
#                    predicted label
# 0  BUSINESS ENABLER/ENTERPRISE MGT
# 1              COMMERCE & RELATION
# 2                    DIGITAL & ICT
# 3                RISK & COMPLIANCE
# 4     STRATEGIC PLAN & DEVELOPMENT

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Test_Y, predictions_SVM)
# Out:
# array([[396,  64, 140,   1,  53],
#        [ 51, 559, 179,   0,  79],
#        [ 76, 114, 842,   0, 100],
#        [ 24,  12,  12,  22,   9],
#        [ 82, 160, 189,   1, 226]], dtype=int64)
